# %%
import librosa
Signal,hz= librosa.load('06-11-22.wav') # me semble plus long sons jupyter que sous spyder

# %%
len(Signal)/hz
# Out:
# 2350.88

# %%
# Son entre 10 minutes et 10 minutes 15
Fenetre=Signal[10*60*hz:(10*60+15)*hz]

# On peut l'écouter et vérifier avec le mp4
import IPython.display as ipd
ipd.Audio(Fenetre,rate=hz) # ne fonctionne que sous jupyter
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
